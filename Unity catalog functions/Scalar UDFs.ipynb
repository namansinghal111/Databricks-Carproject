# %% [markdown]
# ### **SCALAR FUNCTIONS**

# %% [markdown]
# **SQL**

# %%
# %sql
CREATE OR REPLACE FUNCTION databricksansh.bronze.sql_scalar_func(p_par INT)
RETURNS INT   
LANGUAGE SQL 
RETURN p_par*10

# %%
# %sql
SELECT total_amount, databricksansh.bronze.sql_scalar_func(total_amount) FROM databricksansh.silver.sales_enr

# %% [markdown]
# **PYTHON**

# %%
# %sql
CREATE OR REPLACE FUNCTION databricksansh.bronze.python_scalar_func(p_par INT)
RETURNS INT 
LANGUAGE PYTHON 
AS 
$$
    return p_par*10
$$

# %%
# %sql
SELECT total_amount, databricksansh.bronze.python_scalar_func(total_amount) FROM databricksansh.silver.sales_enr

# %%
# %sql
CREATE OR REPLACE FUNCTION  databricksansh.bronze.python_scalar_func_cust(p_par INT)
RETURNS STRING 
LANGUAGE PYTHON 
AS 
$$
    import requests
    response = requests.get(f".v,f.,sl,s,lvsv,dv{p_par}").json()
    response_str = str(response)
    return response_str
$$
