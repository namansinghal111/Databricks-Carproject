# %%
# %sql
CREATE OR REPLACE FUNCTION databricksansh.bronze.udtf(p_para INT)
RETURNS TABLE 
RETURN 
(
  SELECT * FROM databricksansh.SILVER.sales_enr WHERE total_amount > p_para
)

# %%
# %sql
SELECT * FROM databricksansh.bronze.udtf(100)
