# %% [markdown]
# ### **Text Files**

# %%
with open("/Workspace/Users/singhalnaman12@gmail.com/Databricks/silver_layer/file.txt","r") as f:
    content = f.read()

print(content)

# %%
with open("/Workspace/Users/singhalnaman12@gmail.com/Databricks/silver_layer/file.txt","w") as f:
    f.write("my_secret = '1234'")

# %% [markdown]
# ### **Python Files**

# %%
with open("/Workspace/Databricks_Bootcamp/silver_layer/newfile.py","w") as f:
    f.write("my_secret = '1234'")

# %%
import newfile

# %%
newfile.my_secret

# %% [markdown]
# ### **JSON FILES Using Pandas [MAPPING FILES]**

# %%
import pandas as pd

df = pd.read_json("/Workspace/Users/singhalnaman12@gmail.com/Databricks/silver_layer/mappings.json")
df.head()

# %% [markdown]
# ### **Convert it into a PySpark Dataframe**

# %%
df_pyspark = spark.createDataFrame(df)

display(df_pyspark)
