# %%
# %sql
SELECT * FROM parquet.`/Volumes/databricksansh/bronze/autovl/copyinto/part-00000-tid-640365150298883892-48fbe99a-8fe4-49a9-bb0d-eee11064f69b-135-1.c000.snappy.parquet`

# %%
# %sql
DROP TABLE IF EXISTS databricksansh.bronze.copyintotbl

# %%
# %sql
CREATE TABLE databricksansh.bronze.copyintotbl
(
  order_id INT,
  customer_id INT,
  order_date DATE,
  order_amount DOUBLE,
  order_status string
)

# %%
# %sql
COPY INTO databricksansh.bronze.copyintotbl
FROM "/Volumes/databricksansh/bronze/autovl/copyinto/"
FILEFORMAT = PARQUET
FORMAT_OPTIONS ('mergeSchema'= "True")
COPY_OPTIONS ('mergeSchema'= "True")

# %%
# %sql
SELECT * FROM databricksansh.bronze.copyintotbl
